# %%
# !pip install ultralytics

# %%
# !nvidia-smi
# Out:
# Mon Jul  8 10:26:57 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       On  |   00000000:00:1E.0 Off |                    0 |
# | N/A   27C    P8             13W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 14918MiB)
# Setup complete ✅ (8 CPUs, 31.0 GB RAM, 145.7/387.5 GB disk)

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="gGaT09LtDxvT9JAGDnKq")
project = rf.workspace("videoanalytics").project("kitchen-appliances-yxovb")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 46.0 MB/s eta 0:00:000m eta 0:00:010:01:01
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.50, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to kitchen-appliances-2 in yolov8:: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 14351/14351 [00:01<00:00, 10417.77it/s]

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="kitchen-appliances-2/data.yaml" epochs=100 imgsz=640 plots=True
# Out:
# ...
# 100%|███████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 301MB/s]
# New https://pypi.org/project/ultralytics/8.2.51 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.50 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 14918MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO(model="runs/detect/train/weights/best.pt") 

metrics = model.val(data="kitchen-appliances-2/data.yaml", split="test")
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 14918MiB)
# Model summary (fused): 168 layers, 11134872 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /home/udit/video-obj-detection/training/kitchen-appliances-2/test/labels.cache... 234 images, 26 backgrounds, 0 corrupt: 100%|██████████| 234/234 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:04<00:00,  3.63it/s]
#                    all        234        239      0.693      0.765      0.765      0.729
#              air fryer         10         10      0.893       0.84      0.958      0.897
#         bottom freezer         10         12      0.659        0.5       0.57      0.552
#   classic refrigerator          7          7      0.692      0.649      0.663      0.615
#       convection ovens          9         10      0.688        0.3      0.334      0.319
# ...

# %%
metrics.results_dict
# Out:
# {'metrics/precision(B)': 0.6925052139015797,
#  'metrics/recall(B)': 0.7647591803393577,
#  'metrics/mAP50(B)': 0.764988858502004,
#  'metrics/mAP50-95(B)': 0.7286047557524131,
#  'fitness': 0.7322431660273722}
